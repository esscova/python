# %% [markdown]
# ### TENDÊNCIAS DO MOMENTO (RSS)

# %%
import pandas as pd
from trendspyg import download_google_trends_rss
from pprint import pprint

# %%
trends = download_google_trends_rss(geo='BR')

print(f'Encontrado: {len(trends)} trending topics')
print(f'Título primeiro tópico: {trends[0]['trend']}')
# Out:
# Encontrado: 10 trending topics
# Título primeiro tópico: lucro bradesco

# %%
for trend in trends[:3]:
    print(f"{trend['trend']} - {trend['traffic']}")
    if trend['news_articles']:
        print(f"  {trend['news_articles'][0]['headline']}")
# Out:
# lucro bradesco - 200+
#   Bradesco lucra R$ 7 bi no 2º tri, alta de 16%, e propõe aumento de capital
# flamengo copa do brasil - 200+
#   Campeão da Copa do Brasil sub-15, Inter tem geração promissora e jogadores da seleção; veja destaques
# luizianne lins - 500+
#   Guimarães celebra escolha por Luizianne: "Nossa senadora"

# %% [markdown]
# **outputs**

# %%
# csv
trends = download_google_trends_rss(geo='BR',
                                    output_format='csv')
trends[:100]
# Out:
# 'trend,traffic,traffic_min,published,explore_link,image_url,image_source,article_count,top_article_he'

# %%
# json
trends = download_google_trends_rss(geo='BR',
                                    output_format='json')
pprint(trends)
# Out:
# ('[\n'
#  '  {\n'
#  '    "trend": "coquimbo unido x san marcos de arica",\n'
#  '    "traffic": "200+",\n'
#  '    "traffic_min": 200,\n'
#  '    "published": "2026-08-05T18:00:00-07:00",\n'
#  '    "explore_link": "https://trends.google.com/trends/explore?q=coquimbo '
#  'unido x san marcos de arica&geo=BR&hl=en-US",\n'
#  '    "image": {\n'
#  '      "url": '
#  '"https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSHGBfTRtpVFXXhbY5zzgs6Z_xLsYpbT4fBYom9Sr9p40VHKBtaux_lSA13EMA",\n'
#  '      "source": "365Scores"\n'
#  '    },\n'
#  '    "news_articles": [\n'
#  '      {\n'
#  '        "headline": "Qu\\u00e9 canal pasa Coquimbo vs San Marcos hoy: '
#  'd\\u00f3nde ver el partido gratis y EN VIVO de la Copa Chile",\n'
#  '        "url": '
#  '"https://www.365scores.com/es/news/que-canal-pasa-coquimbo-vs-san-marcos/",\n'
#  '        "source": "365Scores",\n'
#  '        "image": '
# ...

# %%
# dataframe
trends = download_google_trends_rss(geo='BR',
                                    output_format='dataframe')
trends
# Out:
#                                   trend traffic  traffic_min  \
# 0  coquimbo unido x san marcos de arica    200+          200
# 1               flamengo copa do brasil    500+          500
# 2                        lucro bradesco    500+          500
# 3                        luizianne lins   1000+         1000
# 4                        lotomania 2959    500+          500
# 5                          orlando city    500+          500
# 6                       núbia cozzolino    200+          200
# 7                            quina 7084   1000+         1000
# 8                         inter miami x    500+          500
# 9                        lotofacil 3754   2000+         2000
#
#                   published  \
# 0 2026-08-05 18:00:00-07:00
# 1 2026-08-05 17:50:00-07:00
# 2 2026-08-05 17:50:00-07:00
# 3 2026-08-05 17:30:00-07:00
# 4 2026-08-05 17:30:00-07:00
# 5 2026-08-05 17:30:00-07:00
# 6 2026-08-05 17:30:00-07:00
# 7 2026-08-05 17:20:00-07:00
# ...

# %% [markdown]
# ### INTERESSE AO LONGO DO TEMPO

# %%
from trendspyg import download_google_trends_interest_over_time

dados = download_google_trends_interest_over_time(
    keyword="bitcoin",
    geo="BR",
    timeframe="today 12-m"
)

print(dados[:5])
# Out:
# [{'date': '2025-08-03T00:00:00+00:00', 'value': 31, 'is_partial': False}, {'date': '2025-08-10T00:00:00+00:00', 'value': 35, 'is_partial': False}, {'date': '2025-08-17T00:00:00+00:00', 'value': 32, 'is_partial': False}, {'date': '2025-08-24T00:00:00+00:00', 'value': 32, 'is_partial': False}, {'date': '2025-08-31T00:00:00+00:00', 'value': 30, 'is_partial': False}]

# %%
pprint(dados[:5])
# Out:
# [   {'date': '2025-08-03T00:00:00+00:00', 'is_partial': False, 'value': 31},
#     {'date': '2025-08-10T00:00:00+00:00', 'is_partial': False, 'value': 35},
#     {'date': '2025-08-17T00:00:00+00:00', 'is_partial': False, 'value': 32},
#     {'date': '2025-08-24T00:00:00+00:00', 'is_partial': False, 'value': 32},
#     {'date': '2025-08-31T00:00:00+00:00', 'is_partial': False, 'value': 30}]

# %%
len(dados)
# Out:
# 53

# %%
for i in dados:
    print(i['date'], i['value'])
# Out:
# 2025-08-03T00:00:00+00:00 31
# 2025-08-10T00:00:00+00:00 35
# 2025-08-17T00:00:00+00:00 32
# 2025-08-24T00:00:00+00:00 32
# 2025-08-31T00:00:00+00:00 30
# 2025-09-07T00:00:00+00:00 34
# 2025-09-14T00:00:00+00:00 30
# 2025-09-21T00:00:00+00:00 29
# 2025-09-28T00:00:00+00:00 31
# 2025-10-05T00:00:00+00:00 43
# 2025-10-12T00:00:00+00:00 42
# 2025-10-19T00:00:00+00:00 35
# 2025-10-26T00:00:00+00:00 36
# 2025-11-02T00:00:00+00:00 46
# 2025-11-09T00:00:00+00:00 43
# 2025-11-16T00:00:00+00:00 67
# 2025-11-23T00:00:00+00:00 54
# 2025-11-30T00:00:00+00:00 51
# 2025-12-07T00:00:00+00:00 39
# 2025-12-14T00:00:00+00:00 40
# 2025-12-21T00:00:00+00:00 35
# 2025-12-28T00:00:00+00:00 34
# 2026-01-04T00:00:00+00:00 36
# 2026-01-11T00:00:00+00:00 32
# 2026-01-18T00:00:00+00:00 32
# 2026-01-25T00:00:00+00:00 42
# 2026-02-01T00:00:00+00:00 100
# 2026-02-08T00:00:00+00:00 67
# 2026-02-15T00:00:00+00:00 46
# 2026-02-22T00:00:00+00:00 49
# 2026-03-01T00:00:00+00:00 45
# 2026-03-08T00:00:00+00:00 36
# ...

# %%
# dataframe
dados = download_google_trends_interest_over_time(
    keyword="bitcoin",
    geo="BR",
    timeframe="today 12-m",
    output_format='dataframe'
)

# %%
dados
# Out:
#                          date  value  is_partial
# 0   2025-08-03T00:00:00+00:00     31       False
# 1   2025-08-10T00:00:00+00:00     35       False
# 2   2025-08-17T00:00:00+00:00     32       False
# 3   2025-08-24T00:00:00+00:00     32       False
# 4   2025-08-31T00:00:00+00:00     30       False
# 5   2025-09-07T00:00:00+00:00     34       False
# 6   2025-09-14T00:00:00+00:00     30       False
# 7   2025-09-21T00:00:00+00:00     29       False
# 8   2025-09-28T00:00:00+00:00     31       False
# 9   2025-10-05T00:00:00+00:00     43       False
# 10  2025-10-12T00:00:00+00:00     42       False
# 11  2025-10-19T00:00:00+00:00     35       False
# 12  2025-10-26T00:00:00+00:00     36       False
# 13  2025-11-02T00:00:00+00:00     46       False
# 14  2025-11-09T00:00:00+00:00     43       False
# 15  2025-11-16T00:00:00+00:00     67       False
# 16  2025-11-23T00:00:00+00:00     54       False
# 17  2025-11-30T00:00:00+00:00     51       False
# ...

# %%
dados.dtypes
# Out:
# date            str
# value         int64
# is_partial     bool
# dtype: object

# %%
dados['date'] = pd.to_datetime(dados['date'])
dados.dtypes
# Out:
# date          datetime64[us, UTC]
# value                       int64
# is_partial                   bool
# dtype: object

# %%
dados.head(3)
# Out:
#                        date  value  is_partial
# 0 2025-08-03 00:00:00+00:00     31       False
# 1 2025-08-10 00:00:00+00:00     35       False
# 2 2025-08-17 00:00:00+00:00     32       False

# %%
dados.date.dt.date
# Out:
# 0     2025-08-03
# 1     2025-08-10
# 2     2025-08-17
# 3     2025-08-24
# 4     2025-08-31
# 5     2025-09-07
# 6     2025-09-14
# 7     2025-09-21
# 8     2025-09-28
# 9     2025-10-05
# 10    2025-10-12
# 11    2025-10-19
# 12    2025-10-26
# 13    2025-11-02
# 14    2025-11-09
# 15    2025-11-16
# 16    2025-11-23
# 17    2025-11-30
# 18    2025-12-07
# 19    2025-12-14
# 20    2025-12-21
# 21    2025-12-28
# 22    2026-01-04
# 23    2026-01-11
# 24    2026-01-18
# 25    2026-01-25
# 26    2026-02-01
# 27    2026-02-08
# 28    2026-02-15
# 29    2026-02-22
# 30    2026-03-01
# 31    2026-03-08
# 32    2026-03-15
# 33    2026-03-22
# 34    2026-03-29
# 35    2026-04-05
# 36    2026-04-12
# 37    2026-04-19
# 38    2026-04-26
# 39    2026-05-03
# 40    2026-05-10
# 41    2026-05-17
# 42    2026-05-24
# 43    2026-05-31
# 44    2026-06-07
# 45    2026-06-14
# 46    2026-06-21
# 47    2026-06-28
# 48    2026-07-05
# 49    2026-07-12
# 50    2026-07-19
# 51    2026-07-26
# ...

# %%
dados['date'] = dados.date.dt.date
dados.head(3)
# Out:
#          date  value  is_partial
# 0  2025-08-03     31       False
# 1  2025-08-10     35       False
# 2  2025-08-17     32       False

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(dados['date'], dados['value'])
plt.show()

# %% [markdown]
# ### TRENDS EXPLORER

# %%
from trendspyg import download_google_trends_explore
env = download_google_trends_explore('bitcoin', geo='BR')
env
# Out:
# {'schema_version': '1.0',
#  'source': 'explore',
#  'keyword': 'bitcoin',
#  'geo': 'BR',
#  'timeframe': 'today 12-m',
#  'fetched_at': '2026-08-06T01:59:15.708386+00:00',
#  'count': 53,
#  'interest_over_time': [{'date': '2025-08-03T00:00:00+00:00',
#    'value': 31,
#    'is_partial': False},
#   {'date': '2025-08-10T00:00:00+00:00', 'value': 35, 'is_partial': False},
#   {'date': '2025-08-17T00:00:00+00:00', 'value': 32, 'is_partial': False},
#   {'date': '2025-08-24T00:00:00+00:00', 'value': 32, 'is_partial': False},
#   {'date': '2025-08-31T00:00:00+00:00', 'value': 30, 'is_partial': False},
#   {'date': '2025-09-07T00:00:00+00:00', 'value': 34, 'is_partial': False},
#   {'date': '2025-09-14T00:00:00+00:00', 'value': 30, 'is_partial': False},
#   {'date': '2025-09-21T00:00:00+00:00', 'value': 29, 'is_partial': False},
#   {'date': '2025-09-28T00:00:00+00:00', 'value': 31, 'is_partial': False},
#   {'date': '2025-10-05T00:00:00+00:00', 'value': 43, 'is_partial': False},
# ...

# %%
env.keys()
# Out:
# dict_keys(['schema_version', 'source', 'keyword', 'geo', 'timeframe', 'fetched_at', 'count', 'interest_over_time', 'related_queries', 'interest_by_region'])

# %%
env['count']
# Out:
# 53

# %%
env['interest_over_time']
# Out:
# [{'date': '2025-08-03T00:00:00+00:00', 'value': 31, 'is_partial': False},
#  {'date': '2025-08-10T00:00:00+00:00', 'value': 35, 'is_partial': False},
#  {'date': '2025-08-17T00:00:00+00:00', 'value': 32, 'is_partial': False},
#  {'date': '2025-08-24T00:00:00+00:00', 'value': 32, 'is_partial': False},
#  {'date': '2025-08-31T00:00:00+00:00', 'value': 30, 'is_partial': False},
#  {'date': '2025-09-07T00:00:00+00:00', 'value': 34, 'is_partial': False},
#  {'date': '2025-09-14T00:00:00+00:00', 'value': 30, 'is_partial': False},
#  {'date': '2025-09-21T00:00:00+00:00', 'value': 29, 'is_partial': False},
#  {'date': '2025-09-28T00:00:00+00:00', 'value': 31, 'is_partial': False},
#  {'date': '2025-10-05T00:00:00+00:00', 'value': 43, 'is_partial': False},
#  {'date': '2025-10-12T00:00:00+00:00', 'value': 42, 'is_partial': False},
#  {'date': '2025-10-19T00:00:00+00:00', 'value': 35, 'is_partial': False},
#  {'date': '2025-10-26T00:00:00+00:00', 'value': 36, 'is_partial': False},
# ...

# %%
env['related_queries']
# Out:
# {'top': [{'query': 'bitcoin hoje',
#    'value': 100,
#    'formatted_value': '100',
#    'link': 'https://trends.google.com/trends/explore?q=bitcoin+hoje&date=today+12-m&geo=BR'},
#   {'query': 'bitcoin dolar',
#    'value': 50,
#    'formatted_value': '50',
#    'link': 'https://trends.google.com/trends/explore?q=bitcoin+dolar&date=today+12-m&geo=BR'},
#   {'query': 'dolar',
#    'value': 50,
#    'formatted_value': '50',
#    'link': 'https://trends.google.com/trends/explore?q=dolar&date=today+12-m&geo=BR'},
#   {'query': 'bitcoin dólar',
#    'value': 34,
#    'formatted_value': '34',
#    'link': 'https://trends.google.com/trends/explore?q=bitcoin+d%C3%B3lar&date=today+12-m&geo=BR'},
#   {'query': 'bitcoin usd',
#    'value': 22,
#    'formatted_value': '22',
#    'link': 'https://trends.google.com/trends/explore?q=bitcoin+usd&date=today+12-m&geo=BR'},
#   {'query': 'bitcoin hoje dólar',
#    'value': 19,
#    'formatted_value': '19',
# ...

# %%
env['related_queries']['rising']
# Out:
# [{'query': 'how to buy bitcoin safely',
#   'value': 11750,
#   'formatted_value': 'Breakout',
#   'link': 'https://trends.google.com/trends/explore?q=how+to+buy+bitcoin+safely&date=today+12-m&geo=BR'},
#  {'query': '1 bitcoin para real brasileiro',
#   'value': 2150,
#   'formatted_value': '+2,150%',
#   'link': 'https://trends.google.com/trends/explore?q=1+bitcoin+para+real+brasileiro&date=today+12-m&geo=BR'},
#  {'query': 'what is bitcoin',
#   'value': 1700,
#   'formatted_value': '+1,700%',
#   'link': 'https://trends.google.com/trends/explore?q=what+is+bitcoin&date=today+12-m&geo=BR'},
#  {'query': 'coin11',
#   'value': 600,
#   'formatted_value': '+600%',
#   'link': 'https://trends.google.com/trends/explore?q=coin11&date=today+12-m&geo=BR'},
#  {'query': 'valor de 1 bitcoin em dólar',
#   'value': 300,
#   'formatted_value': '+300%',
#   'link': 'https://trends.google.com/trends/explore?q=valor+de+1+bitcoin+em+d%C3%B3lar&date=today+12-m&geo=BR'},
#  {'query': 'gold11',
# ...

# %%
len(env['related_queries']['rising'])
# Out:
# 20

# %%
env['interest_by_region']
# Out:
# [{'geo_code': 'BR-SC', 'geo_name': 'State of Santa Catarina', 'value': 100},
#  {'geo_code': 'BR-MT', 'geo_name': 'State of Mato Grosso', 'value': 97},
#  {'geo_code': 'BR-DF', 'geo_name': 'Federal District', 'value': 96},
#  {'geo_code': 'BR-PA', 'geo_name': 'State of Pará', 'value': 95},
#  {'geo_code': 'BR-SP', 'geo_name': 'State of São Paulo', 'value': 94},
#  {'geo_code': 'BR-RS', 'geo_name': 'State of Rio Grande do Sul', 'value': 94},
#  {'geo_code': 'BR-MS', 'geo_name': 'State of Mato Grosso do Sul', 'value': 92},
#  {'geo_code': 'BR-RJ', 'geo_name': 'State of Rio de Janeiro', 'value': 87},
#  {'geo_code': 'BR-TO', 'geo_name': 'State of Tocantins', 'value': 86},
#  {'geo_code': 'BR-ES', 'geo_name': 'State of Espírito Santo', 'value': 86},
#  {'geo_code': 'BR-RR', 'geo_name': 'State of Roraima', 'value': 82},
#  {'geo_code': 'BR-CE', 'geo_name': 'State of Ceará', 'value': 82},
#  {'geo_code': 'BR-PR', 'geo_name': 'State of Paraná', 'value': 82},
# ...

# %% [markdown]
# ### COMPARAÇÃO DE PALAVRAS-CHAVE

# %%
from trendspyg import download_google_trends_comparison

# %%
env = download_google_trends_comparison(["bitcoin", "ethereum", "solana"], geo="BR")
env
# Out:
# {'schema_version': '1.0',
#  'source': 'explore_comparison',
#  'keywords': ['bitcoin', 'ethereum', 'solana'],
#  'geo': 'BR',
#  'timeframe': 'today 12-m',
#  'fetched_at': '2026-08-06T18:38:16.067045+00:00',
#  'count': 53,
#  'averages': {'bitcoin': 37, 'ethereum': 4, 'solana': 2},
#  'interest_over_time': [{'date': '2025-08-03T00:00:00+00:00',
#    'values': {'bitcoin': 31, 'ethereum': 5, 'solana': 2},
#    'is_partial': False},
#   {'date': '2025-08-10T00:00:00+00:00',
#    'values': {'bitcoin': 35, 'ethereum': 7, 'solana': 2},
#    'is_partial': False},
#   {'date': '2025-08-17T00:00:00+00:00',
#    'values': {'bitcoin': 32, 'ethereum': 6, 'solana': 2},
#    'is_partial': False},
#   {'date': '2025-08-24T00:00:00+00:00',
#    'values': {'bitcoin': 33, 'ethereum': 6, 'solana': 2},
#    'is_partial': False},
#   {'date': '2025-08-31T00:00:00+00:00',
#    'values': {'bitcoin': 31, 'ethereum': 4, 'solana': 2},
#    'is_partial': False},
#   {'date': '2025-09-07T00:00:00+00:00',
# ...

# %%
env.keys()
# Out:
# dict_keys(['schema_version', 'source', 'keywords', 'geo', 'timeframe', 'fetched_at', 'count', 'averages', 'interest_over_time', 'interest_by_region'])

# %%
env['averages']
# Out:
# {'bitcoin': 37, 'ethereum': 4, 'solana': 2}

# %%
env['count']
# Out:
# 53

# %%
env['interest_over_time'][:5]
# Out:
# [{'date': '2025-08-03T00:00:00+00:00',
#   'values': {'bitcoin': 31, 'ethereum': 5, 'solana': 2},
#   'is_partial': False},
#  {'date': '2025-08-10T00:00:00+00:00',
#   'values': {'bitcoin': 35, 'ethereum': 7, 'solana': 2},
#   'is_partial': False},
#  {'date': '2025-08-17T00:00:00+00:00',
#   'values': {'bitcoin': 32, 'ethereum': 6, 'solana': 2},
#   'is_partial': False},
#  {'date': '2025-08-24T00:00:00+00:00',
#   'values': {'bitcoin': 33, 'ethereum': 6, 'solana': 2},
#   'is_partial': False},
#  {'date': '2025-08-31T00:00:00+00:00',
#   'values': {'bitcoin': 31, 'ethereum': 4, 'solana': 2},
#   'is_partial': False}]

# %%
env['interest_by_region'][:3]
# Out:
# [{'geo_code': 'BR-SC',
#   'geo_name': 'State of Santa Catarina',
#   'values': {'bitcoin': 86, 'ethereum': 10, 'solana': 4},
#   'top_keyword': 'bitcoin'},
#  {'geo_code': 'BR-MT',
#   'geo_name': 'State of Mato Grosso',
#   'values': {'bitcoin': 87, 'ethereum': 9, 'solana': 4},
#   'top_keyword': 'bitcoin'},
#  {'geo_code': 'BR-DF',
#   'geo_name': 'Federal District',
#   'values': {'bitcoin': 88, 'ethereum': 7, 'solana': 5},
#   'top_keyword': 'bitcoin'}]

# %%
env['interest_by_region'][0]['geo_code']
env['interest_by_region'][0]['geo_name']
# Out:
# 'State of Santa Catarina'

# %%
df_regiao = pd.DataFrame(env['interest_by_region'])
df_regiao
# Out:
#    geo_code                      geo_name  \
# 0     BR-SC       State of Santa Catarina
# 1     BR-MT          State of Mato Grosso
# 2     BR-DF              Federal District
# 3     BR-PA                 State of Pará
# 4     BR-SP            State of São Paulo
# 5     BR-RS    State of Rio Grande do Sul
# 6     BR-MS   State of Mato Grosso do Sul
# 7     BR-RJ       State of Rio de Janeiro
# 8     BR-ES       State of Espírito Santo
# 9     BR-TO            State of Tocantins
# 10    BR-RR              State of Roraima
# 11    BR-CE                State of Ceará
# 12    BR-PR               State of Paraná
# 13    BR-MG         State of Minas Gerais
# 14    BR-RO             State of Rondônia
# 15    BR-GO                State of Goiás
# 16    BR-AM             State of Amazonas
# 17    BR-AL              State of Alagoas
# 18    BR-RN  State of Rio Grande do Norte
# 19    BR-BA                State of Bahia
# 20    BR-MA             State of Maranhão
# ...

# %%
pd.DataFrame(df_regiao['values'].to_list())
# Out:
#     bitcoin  ethereum  solana
# 0        86        10       4
# 1        87         9       4
# 2        88         7       5
# 3        93         5       2
# 4        85         9       6
# 5        87         9       4
# 6        91         6       3
# 7        86         8       6
# 8        88         7       5
# 9        90         6       4
# 10       82        15       3
# 11       91         6       3
# 12       87         8       5
# 13       86         9       5
# 14       87         6       7
# 15       89         6       5
# 16       92         4       4
# 17       89         7       4
# 18       90         6       4
# 19       89         7       4
# 20       89         7       4
# 21       89         5       6
# 22       87         7       6
# 23       85         9       6
# 24       88         7       5
# 25       90         6       4
# 26       85         9       6

# %%
df_regiao = pd.concat([df_regiao, pd.DataFrame(df_regiao['values'].to_list())], axis=1)
df_regiao
# Out:
#    geo_code                      geo_name  \
# 0     BR-SC       State of Santa Catarina
# 1     BR-MT          State of Mato Grosso
# 2     BR-DF              Federal District
# 3     BR-PA                 State of Pará
# 4     BR-SP            State of São Paulo
# 5     BR-RS    State of Rio Grande do Sul
# 6     BR-MS   State of Mato Grosso do Sul
# 7     BR-RJ       State of Rio de Janeiro
# 8     BR-ES       State of Espírito Santo
# 9     BR-TO            State of Tocantins
# 10    BR-RR              State of Roraima
# 11    BR-CE                State of Ceará
# 12    BR-PR               State of Paraná
# 13    BR-MG         State of Minas Gerais
# 14    BR-RO             State of Rondônia
# 15    BR-GO                State of Goiás
# 16    BR-AM             State of Amazonas
# 17    BR-AL              State of Alagoas
# 18    BR-RN  State of Rio Grande do Norte
# 19    BR-BA                State of Bahia
# 20    BR-MA             State of Maranhão
# ...

# %%
df_regiao.drop(columns=['values'], inplace=True)
df_regiao
# Out:
#    geo_code                      geo_name top_keyword  bitcoin  ethereum  \
# 0     BR-SC       State of Santa Catarina     bitcoin       86        10
# 1     BR-MT          State of Mato Grosso     bitcoin       87         9
# 2     BR-DF              Federal District     bitcoin       88         7
# 3     BR-PA                 State of Pará     bitcoin       93         5
# 4     BR-SP            State of São Paulo     bitcoin       85         9
# 5     BR-RS    State of Rio Grande do Sul     bitcoin       87         9
# 6     BR-MS   State of Mato Grosso do Sul     bitcoin       91         6
# 7     BR-RJ       State of Rio de Janeiro     bitcoin       86         8
# 8     BR-ES       State of Espírito Santo     bitcoin       88         7
# 9     BR-TO            State of Tocantins     bitcoin       90         6
# 10    BR-RR              State of Roraima     bitcoin       82        15
# 11    BR-CE                State of Ceará     bitcoin       91         6
# ...

# %%
df = download_google_trends_comparison(["bitcoin", "ethereum"], output_format="dataframe")

# %%
df
# Out:
#                          date  bitcoin  ethereum  is_partial
# 0   2025-08-03T00:00:00+00:00       36        11       False
# 1   2025-08-10T00:00:00+00:00       36        16       False
# 2   2025-08-17T00:00:00+00:00       29        10       False
# 3   2025-08-24T00:00:00+00:00       27        10       False
# 4   2025-08-31T00:00:00+00:00       26         7       False
# 5   2025-09-07T00:00:00+00:00       22         6       False
# 6   2025-09-14T00:00:00+00:00       26         6       False
# 7   2025-09-21T00:00:00+00:00       27         7       False
# 8   2025-09-28T00:00:00+00:00       29         6       False
# 9   2025-10-05T00:00:00+00:00       38         8       False
# 10  2025-10-12T00:00:00+00:00       43         7       False
# 11  2025-10-19T00:00:00+00:00       31         6       False
# 12  2025-10-26T00:00:00+00:00       32         6       False
# 13  2025-11-02T00:00:00+00:00       41         8       False
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12,8))
plt.plot(pd.to_datetime(df['date']), df['bitcoin'], color='red', label='bitcoin')
plt.plot(pd.to_datetime(df['date']), df['ethereum'], color='blue', label='ethereum')
plt.legend()
plt.show()

# %% [markdown]
# ### CONSULTAS RELACIONADAS (RELATED QUERIES)

# %%
from trendspyg              import download_google_trends_explore
from trendspyg.exceptions   import DownloadError, BrowserError
from typing import Tuple
import pandas as pd
DEFAULT_GEO         = 'BR'
DEFAULT_TIMEFRAME   = 'today 12-m'

# %%
def get_related_queries(keyword:str, geo:str, timeframe:str) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Retorna consultas relacionados (Top e Rising) para uma palavra-chave.

    Args:
        - keyword: palavra-chave pesquisada
        - geo: código ISO do país
        - timeframe: intervalo da pesqauisa
    Returns:
        tuple[pd.DataFrame, pd.DataFrame] -> (top_queries, rising_queries)
    """
    try:
        data = download_google_trends_explore(
            keyword=keyword,
            geo=geo,
            timeframe=timeframe,
        )

        related = data.get('related_queries', {})
        top     = pd.DataFrame(related.get('top', []))
        rising  = pd.DataFrame(related.get('rising', []))

        return top, rising
    
    except DownloadError as e:
        raise RuntimeError("Google Trends limitou a consulta temporariamente") from e
    except BrowserError as e:
        raise RuntimeError('Google Trends mudou a página, atualize o trendspyg ou tente novamente mais tarde.')
    except Exception as e:
        raise RuntimeError(f"Erro ao consultar o Google Trends: {e}") from e

# %%
top, rising = get_related_queries(keyword='Python',
                                      geo=DEFAULT_GEO,
                                      timeframe=DEFAULT_TIMEFRAME)

# %%
top
# Out:
#                           query  value formatted_value  \
# 0                 python online    100             100
# 1               python download     96              96
# 2                        github     65              65
# 3                install python     60              60
# 4                  curso python     38              38
# 5                        vscode     37              37
# 6            programming python     34              34
# 7                        pandas     30              30
# 8               instalar python     29              29
# 9                 pandas python     29              29
# 10              curso de python     27              27
# 11                         java     26              26
# 12                      vs code     24              24
# 13                 monty python     23              23
# 14         python data analysis     23              23
# 15             linguagem python     23              23
# ...

# %%
rising
# Out:
#                           query  value formatted_value  \
# 0               walmart near me  19000        Breakout
# 1    learn python for beginners  14900        Breakout
# 2   python programming tutorial   7750        Breakout
# 3                  lidl near me   2850         +2,850%
# 4          python web framework   1450         +1,450%
# 5          python data analysis    850           +850%
# 6           how to learn python    700           +700%
# 7            programming python    300           +300%
# 8                     wikipedia    300           +300%
# 9                        github    110           +110%
# 10                      vs code     90            +90%
#
#                                                  link
# 0   https://trends.google.com/trends/explore?q=wal...
# 1   https://trends.google.com/trends/explore?q=lea...
# 2   https://trends.google.com/trends/explore?q=pyt...
# 3   https://trends.google.com/trends/explore?q=lid...
# ...

# %%
if not top.empty and not rising.empty:
    print('\nTOP QUERIES\n')
    print(top)

    print('\nRISING QUERIES\n')
    print(rising)
# Out:
# TOP QUERIES
#
#                           query  value formatted_value  \
# 0                 python online    100             100
# 1               python download     96              96
# 2                        github     65              65
# 3                install python     60              60
# 4                  curso python     38              38
# 5                        vscode     37              37
# 6            programming python     34              34
# 7                        pandas     30              30
# 8               instalar python     29              29
# 9                 pandas python     29              29
# 10              curso de python     27              27
# 11                         java     26              26
# 12                      vs code     24              24
# 13                 monty python     23              23
# 14         python data analysis     23              23
# 15             linguagem python     23              23
# ...

# %% [markdown]
# ### INTERESSE RELATIVO POR REGIÃO

# %%
from trendspyg import download_google_trends_explore

data = download_google_trends_explore(
    keyword="ozzy",
    geo="BR",
    timeframe="today 12-m"
)

# %%
data.keys()
# Out:
# dict_keys(['schema_version', 'source', 'keyword', 'geo', 'timeframe', 'fetched_at', 'count', 'interest_over_time', 'related_queries', 'interest_by_region'])

# %%
data['interest_by_region']
# Out:
# [{'geo_code': 'BR-SP', 'geo_name': 'State of São Paulo', 'value': 100},
#  {'geo_code': 'BR-SC', 'geo_name': 'State of Santa Catarina', 'value': 87},
#  {'geo_code': 'BR-RS', 'geo_name': 'State of Rio Grande do Sul', 'value': 84},
#  {'geo_code': 'BR-PR', 'geo_name': 'State of Paraná', 'value': 82},
#  {'geo_code': 'BR-DF', 'geo_name': 'Federal District', 'value': 78},
#  {'geo_code': 'BR-ES', 'geo_name': 'State of Espírito Santo', 'value': 78},
#  {'geo_code': 'BR-CE', 'geo_name': 'State of Ceará', 'value': 70},
#  {'geo_code': 'BR-MG', 'geo_name': 'State of Minas Gerais', 'value': 70},
#  {'geo_code': 'BR-AP', 'geo_name': 'State of Amapá', 'value': 68},
#  {'geo_code': 'BR-AM', 'geo_name': 'State of Amazonas', 'value': 64},
#  {'geo_code': 'BR-GO', 'geo_name': 'State of Goiás', 'value': 60},
#  {'geo_code': 'BR-RN',
#   'geo_name': 'State of Rio Grande do Norte',
#   'value': 60},
#  {'geo_code': 'BR-RJ', 'geo_name': 'State of Rio de Janeiro', 'value': 58},
# ...

# %%
df = pd.DataFrame(data['interest_by_region'])\
    .rename(columns={'geo_code' : 'codigo',
                     'geo_name' : 'estado',
                     'value'    : 'indice'})
df
# Out:
#    codigo                        estado  indice
# 0   BR-SP            State of São Paulo     100
# 1   BR-SC       State of Santa Catarina      87
# 2   BR-RS    State of Rio Grande do Sul      84
# 3   BR-PR               State of Paraná      82
# 4   BR-DF              Federal District      78
# 5   BR-ES       State of Espírito Santo      78
# 6   BR-CE                State of Ceará      70
# 7   BR-MG         State of Minas Gerais      70
# 8   BR-AP                State of Amapá      68
# 9   BR-AM             State of Amazonas      64
# 10  BR-GO                State of Goiás      60
# 11  BR-RN  State of Rio Grande do Norte      60
# 12  BR-RJ       State of Rio de Janeiro      58
# 13  BR-MS   State of Mato Grosso do Sul      55
# 14  BR-SE              State of Sergipe      54
# 15  BR-PE           State of Pernambuco      54
# 16  BR-PA                 State of Pará      54
# 17  BR-PB              State of Paraíba      54
# 18  BR-PI                State of Piauí      53
# ...

# %%
df['estado'] \
    .str.replace('State of ','', regex=False) \
    .str.replace('Federal District', 'Distrito Federal')
# Out:
# 0               São Paulo
# 1          Santa Catarina
# 2       Rio Grande do Sul
# 3                  Paraná
# 4        Distrito Federal
# 5          Espírito Santo
# 6                   Ceará
# 7            Minas Gerais
# 8                   Amapá
# 9                Amazonas
# 10                  Goiás
# 11    Rio Grande do Norte
# 12         Rio de Janeiro
# 13     Mato Grosso do Sul
# 14                Sergipe
# 15             Pernambuco
# 16                   Pará
# 17                Paraíba
# 18                  Piauí
# 19                   Acre
# 20            Mato Grosso
# 21               Rondônia
# 22              Tocantins
# 23               Maranhão
# 24                Alagoas
# 25                  Bahia
# 26                Roraima
# Name: estado, dtype: str

# %%
df['estado'] = df['estado'] \
    .str.replace('State of ','', regex=False) \
    .str.replace('Federal District', 'Distrito Federal')

# %%
df
# Out:
#    codigo               estado  indice
# 0   BR-SP            São Paulo     100
# 1   BR-SC       Santa Catarina      87
# 2   BR-RS    Rio Grande do Sul      84
# 3   BR-PR               Paraná      82
# 4   BR-DF     Distrito Federal      78
# 5   BR-ES       Espírito Santo      78
# 6   BR-CE                Ceará      70
# 7   BR-MG         Minas Gerais      70
# 8   BR-AP                Amapá      68
# 9   BR-AM             Amazonas      64
# 10  BR-GO                Goiás      60
# 11  BR-RN  Rio Grande do Norte      60
# 12  BR-RJ       Rio de Janeiro      58
# 13  BR-MS   Mato Grosso do Sul      55
# 14  BR-SE              Sergipe      54
# 15  BR-PE           Pernambuco      54
# 16  BR-PA                 Pará      54
# 17  BR-PB              Paraíba      54
# 18  BR-PI                Piauí      53
# 19  BR-AC                 Acre      51
# 20  BR-MT          Mato Grosso      51
# 21  BR-RO             Rondônia      48
# 22  BR-TO            Tocantins      43
# ...

# %%
df['codigo'].str[-2:]
# Out:
# 0     SP
# 1     SC
# 2     RS
# 3     PR
# 4     DF
# 5     ES
# 6     CE
# 7     MG
# 8     AP
# 9     AM
# 10    GO
# 11    RN
# 12    RJ
# 13    MS
# 14    SE
# 15    PE
# 16    PA
# 17    PB
# 18    PI
# 19    AC
# 20    MT
# 21    RO
# 22    TO
# 23    MA
# 24    AL
# 25    BA
# 26    RR
# Name: codigo, dtype: str

# %%
df['uf'] = df['codigo'].str[-2:]
df.drop(columns=['codigo'], inplace=True)
df = df[['uf', 'estado', 'indice']]
df
# Out:
#     uf               estado  indice
# 0   SP            São Paulo     100
# 1   SC       Santa Catarina      87
# 2   RS    Rio Grande do Sul      84
# 3   PR               Paraná      82
# 4   DF     Distrito Federal      78
# 5   ES       Espírito Santo      78
# 6   CE                Ceará      70
# 7   MG         Minas Gerais      70
# 8   AP                Amapá      68
# 9   AM             Amazonas      64
# 10  GO                Goiás      60
# 11  RN  Rio Grande do Norte      60
# 12  RJ       Rio de Janeiro      58
# 13  MS   Mato Grosso do Sul      55
# 14  SE              Sergipe      54
# 15  PE           Pernambuco      54
# 16  PA                 Pará      54
# 17  PB              Paraíba      54
# 18  PI                Piauí      53
# 19  AC                 Acre      51
# 20  MT          Mato Grosso      51
# 21  RO             Rondônia      48
# 22  TO            Tocantins      43
# 23  MA             Maranhão      43
# 24  AL              Alagoas      42
# ...

# %%
plt.barh(df['estado'], df['indice'])
plt.gca().invert_yaxis()
